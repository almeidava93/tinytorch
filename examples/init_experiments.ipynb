# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.uniform(size=1000000), kind="hist")

plt.show()

# %%
random.uniform(size=(2, 3))
# Out:
# array([[0.1735442 , 0.7307221 , 0.13436498],
#        [0.0342427 , 0.50089617, 0.94140088]])

# %%
type(random.uniform())
# Out:
# float

# %%
type(random.normal)
# Out:
# method
